# %% [markdown]
# Pandas is an open-source library.
# It is a Python package that offers various data structures and operations for manipulating numerical data and time series.
# It is mainly popular for importing and analyzing data much easier.
# Pandas is fast and it has high-performance & productivity for users.
#
# CSV (Comma Separated Values) is a simple file format used to store tabular data, such as a spreadsheet or database.
#
# Tabular data is data that is structured into rows, each of which contains informations.

# %%
 import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Prostate_Cancer.csv')
print(df.to_string())
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  compactness  symmetry  fractal_dimension
# 0     1                M    23.0       12        151   954       0.143        0.278     0.242              0.079
# 1     2                B     9.0       13        133  1326       0.143        0.079     0.181              0.057
# 2     3                M     NaN       27        130  1203       0.125        0.160     0.207              0.060
# 3     4                M    14.0       16         78   386       0.070        0.284     0.260              0.097
# 4     5                M     9.0       19        135  1297       0.141        0.133     0.181              0.059
# 5     6                B    25.0       25         83   477       0.128        0.170     0.209              0.076
# 6     7                M    16.0       26        120  1040       0.095        0.109     0.179              0.057
# ...

# %% [markdown]
# - > >Viewing data

# %% [markdown]
# - >top and bottom rows of the frame

# %%
df.head(5)
# Out:
#    id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   1                M    23.0       12        151   954       0.143
# 1   2                B     9.0       13        133  1326       0.143
# 2   3                M     NaN       27        130  1203       0.125
# 3   4                M    14.0       16         78   386       0.070
# 4   5                M     9.0       19        135  1297       0.141
#
#    compactness  symmetry  fractal_dimension
# 0        0.278     0.242              0.079
# 1        0.079     0.181              0.057
# 2        0.160     0.207              0.060
# 3        0.284     0.260              0.097
# 4        0.133     0.181              0.059

# %%
df.tail(5)
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 95   96                M    23.0       16        132  1264       0.091
# 96   97                B    22.0       14         78   451       0.105
# 97   98                B    19.0       27         62   295       0.102
# 98   99                B    21.0       24         74   413       0.090
# 99  100                M    16.0       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 95        0.131     0.210              0.056
# 96        0.071     0.190              0.066
# 97        0.053     0.135              0.069
# 98        0.075     0.162              0.066
# 99        0.114     0.188              0.064

# %% [markdown]
# - >Display the index, columns

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.columns
# Out:
# Index(['id', 'diagnosis_result', 'radius', 'texture', 'perimeter', 'area',
#        'smoothness', 'compactness', 'symmetry', 'fractal_dimension'],
#       dtype='object')

# %% [markdown]
# - >NumPy arrays have one dtype for the entire array, while pandas DataFrames have one dtype per column

# %%
df.to_numpy()
# Out:
# array([[1, 'M', 23.0, 12, 151, 954, 0.143, 0.278, 0.242, 0.079],
#        [2, 'B', 9.0, 13, 133, 1326, 0.143, 0.079, 0.181, 0.057],
#        [3, 'M', nan, 27, 130, 1203, 0.125, 0.16, 0.207, 0.06],
#        [4, 'M', 14.0, 16, 78, 386, 0.07, 0.284, 0.26, 0.097],
#        [5, 'M', 9.0, 19, 135, 1297, 0.141, 0.133, 0.181, 0.059],
#        [6, 'B', 25.0, 25, 83, 477, 0.128, 0.17, 0.209, 0.076],
#        [7, 'M', 16.0, 26, 120, 1040, 0.095, 0.109, 0.179, 0.057],
#        [8, 'M', 15.0, 18, 90, 578, 0.119, 0.165, 0.22, 0.075],
#        [9, 'M', 19.0, 24, 88, 520, 0.127, 0.193, 0.235, 0.074],
#        [10, 'M', 25.0, 11, 84, 476, 0.119, 0.24, 0.203, 0.082],
#        [11, 'M', 24.0, 21, 103, 798, 0.082, 0.067, 0.153, 0.057],
#        [12, 'M', 17.0, 15, 104, 781, 0.097, 0.129, 0.184, 0.061],
#        [13, 'B', 14.0, 15, 132, 1123, 0.097, nan, 0.24, 0.078],
#        [14, 'M', 12.0, 22, 104, 783, 0.084, 0.1, 0.185, 0.053],
#        [15, 'M', 12.0, 13, 94, 578, 0.113, 0.229, 0.207, 0.077],
# ...

# %% [markdown]
# - >quick statistic summary of your data

# %%
df.describe()
# Out:
#                id     radius     texture   perimeter         area  smoothness  \
# count  100.000000  99.000000  100.000000  100.000000   100.000000  100.000000
# mean    50.500000  16.808081   18.230000   96.780000   702.880000    0.102730
# std     29.011492   4.885791    5.192954   23.676089   319.710895    0.014642
# min      1.000000   9.000000   11.000000   52.000000   202.000000    0.070000
# 25%     25.750000  12.000000   14.000000   82.500000   476.750000    0.093500
# 50%     50.500000  17.000000   17.500000   94.000000   644.000000    0.102000
# 75%     75.250000  21.000000   22.250000  114.250000   917.000000    0.112000
# max    100.000000  25.000000   27.000000  172.000000  1878.000000    0.143000
#
#        compactness    symmetry  fractal_dimension
# count    97.000000  100.000000          98.000000
# mean      0.124598    0.193170           0.064816
# std       0.059940    0.030785           0.008160
# min       0.038000    0.135000           0.053000
# ...

# %% [markdown]
# - >Transposing your data

# %%
df.T
# Out:
#                       0      1      2      3      4      5      6      7   \
# id                     1      2      3      4      5      6      7      8
# diagnosis_result       M      B      M      M      M      B      M      M
# radius              23.0    9.0    NaN   14.0    9.0   25.0   16.0   15.0
# texture               12     13     27     16     19     25     26     18
# perimeter            151    133    130     78    135     83    120     90
# area                 954   1326   1203    386   1297    477   1040    578
# smoothness         0.143  0.143  0.125   0.07  0.141  0.128  0.095  0.119
# compactness        0.278  0.079   0.16  0.284  0.133   0.17  0.109  0.165
# symmetry           0.242  0.181  0.207   0.26  0.181  0.209  0.179   0.22
# fractal_dimension  0.079  0.057   0.06  0.097  0.059  0.076  0.057  0.075
#
#                       8      9   ...     90     91     92     93     94  \
# id                     9     10  ...     91     92     93     94     95
# ...

# %% [markdown]
# - >Sorting by an axis

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 99  100                M    16.0       27         94   643       0.098
# 98   99                B    21.0       24         74   413       0.090
# 97   98                B    19.0       27         62   295       0.102
# 96   97                B    22.0       14         78   451       0.105
# 95   96                M    23.0       16        132  1264       0.091
# ..  ...              ...     ...      ...        ...   ...         ...
# 4     5                M     9.0       19        135  1297       0.141
# 3     4                M    14.0       16         78   386       0.070
# 2     3                M     NaN       27        130  1203       0.125
# 1     2                B     9.0       13        133  1326       0.143
# 0     1                M    23.0       12        151   954       0.143
#
#     compactness  symmetry  fractal_dimension
# 99        0.114     0.188              0.064
# ...

# %% [markdown]
# - >Sorting by values

# %%
df.sort_values(by="radius")
# Out:
#     id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 24  25                M     9.0       13        110   905       0.112
# 1    2                B     9.0       13        133  1326       0.143
# 4    5                M     9.0       19        135  1297       0.141
# 71  72                B     9.0       26         59   244       0.098
# 35  36                M    10.0       13        110   870       0.096
# ..  ..              ...     ...      ...        ...   ...         ...
# 49  50                B    25.0       11         87   561       0.088
# 52  53                B    25.0       15         76   438       0.083
# 5    6                B    25.0       25         83   477       0.128
# 84  85                B    25.0       21         77   443       0.097
# 2    3                M     NaN       27        130  1203       0.125
#
#     compactness  symmetry  fractal_dimension
# 24        0.146     0.200              0.063
# ...

# %% [markdown]
# - >>Selection

# %% [markdown]
# - >Selecting a single column

# %%
df["radius"]
# Out:
# 0     23.0
# 1      9.0
# 2      NaN
# 3     14.0
# 4      9.0
#       ...
# 95    23.0
# 96    22.0
# 97    19.0
# 98    21.0
# 99    16.0
# Name: radius, Length: 100, dtype: float64

# %%
df[0:11]
# Out:
#     id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0    1                M    23.0       12        151   954       0.143
# 1    2                B     9.0       13        133  1326       0.143
# 2    3                M     NaN       27        130  1203       0.125
# 3    4                M    14.0       16         78   386       0.070
# 4    5                M     9.0       19        135  1297       0.141
# 5    6                B    25.0       25         83   477       0.128
# 6    7                M    16.0       26        120  1040       0.095
# 7    8                M    15.0       18         90   578       0.119
# 8    9                M    19.0       24         88   520       0.127
# 9   10                M    25.0       11         84   476       0.119
# 10  11                M    24.0       21        103   798       0.082
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# ...

# %% [markdown]
# - >selection using a label

# %%
df.loc[0]
# Out:
# id                       1
# diagnosis_result         M
# radius                23.0
# texture                 12
# perimeter              151
# area                   954
# smoothness           0.143
# compactness          0.278
# symmetry             0.242
# fractal_dimension    0.079
# Name: 0, dtype: object

# %% [markdown]
# - >Selecting on a multi-axis by label

# %%
df.loc[:, ["area", "symmetry"]]
# Out:
#     area  symmetry
# 0    954     0.242
# 1   1326     0.181
# 2   1203     0.207
# 3    386     0.260
# 4   1297     0.181
# ..   ...       ...
# 95  1264     0.210
# 96   451     0.190
# 97   295     0.135
# 98   413     0.162
# 99   643     0.188
#
# [100 rows x 2 columns]

# %% [markdown]
# - >Showing label slicing, both endpoints are included

# %%
df.loc[ 5: 11, ["area", "symmetry"]]
# Out:
#     area  symmetry
# 5    477     0.209
# 6   1040     0.179
# 7    578     0.220
# 8    520     0.235
# 9    476     0.203
# 10   798     0.153
# 11   781     0.184

# %% [markdown]
# - >Reduction in the dimensions of the returned object

# %%
print(df.loc[ 5, ["area", "symmetry"]])
print(df.to_string())
# Out:
# area          477
# symmetry    0.209
# Name: 5, dtype: object
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  compactness  symmetry  fractal_dimension
# 0     1                M    23.0       12        151   954       0.143        0.278     0.242              0.079
# 1     2                B     9.0       13        133  1326       0.143        0.079     0.181              0.057
# 2     3                M     NaN       27        130  1203       0.125        0.160     0.207              0.060
# 3     4                M    14.0       16         78   386       0.070        0.284     0.260              0.097
# 4     5                M     9.0       19        135  1297       0.141        0.133     0.181              0.059
# 5     6                B    25.0       25         83   477       0.128        0.170     0.209              0.076
# 6     7                M    16.0       26        120  1040       0.095        0.109     0.179              0.057
# ...

# %% [markdown]
# - >Select via the position of the passed integers

# %%
df.iloc[0]
# Out:
# id                       1
# diagnosis_result         M
# radius                23.0
# texture                 12
# perimeter              151
# area                   954
# smoothness           0.143
# compactness          0.278
# symmetry             0.242
# fractal_dimension    0.079
# Name: 0, dtype: object

# %% [markdown]
# - >By integer slices

# %%
df.iloc[0:3,0:2]
# Out:
#    id diagnosis_result
# 0   1                M
# 1   2                B
# 2   3                M

# %% [markdown]
# - >By lists of integer position locations

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#    id  radius
# 1   2     9.0
# 2   3     NaN
# 4   5     9.0

# %% [markdown]
# - >Boolean indexing
# Using a single column’s values to select data

# %%
df[df["radius"] > 20]
# Out:
#     id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0    1                M    23.0       12        151   954       0.143
# 5    6                B    25.0       25         83   477       0.128
# 9   10                M    25.0       11         84   476       0.119
# 10  11                M    24.0       21        103   798       0.082
# 15  16                M    22.0       19         97   659       0.114
# 31  32                M    23.0       26         78   441       0.111
# 37  38                B    21.0       11         83   524       0.090
# 40  41                M    24.0       16         86   563       0.082
# 46  47                B    22.0       12         52   202       0.086
# 49  50                B    25.0       11         87   561       0.088
# 52  53                B    25.0       15         76   438       0.083
# 58  59                B    22.0       15         83   527       0.081
# ...

# %% [markdown]
# - >Using the isin() method for filtering

# %%
df2 = df.copy()
df2["New_Column"]=(np.arange(0,len(df2)))
df2
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0     1                M    23.0       12        151   954       0.143
# 1     2                B     9.0       13        133  1326       0.143
# 2     3                M     NaN       27        130  1203       0.125
# 3     4                M    14.0       16         78   386       0.070
# 4     5                M     9.0       19        135  1297       0.141
# ..  ...              ...     ...      ...        ...   ...         ...
# 95   96                M    23.0       16        132  1264       0.091
# 96   97                B    22.0       14         78   451       0.105
# 97   98                B    19.0       27         62   295       0.102
# 98   99                B    21.0       24         74   413       0.090
# 99  100                M    16.0       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension  New_Column
# 0         0.278     0.242              0.079           0
# ...

# %%
df2[df2["New_Column"].isin([2, 4])]

# %% [markdown]
# - >Setting values by label

# %%
df2.at[2,"diagnosis_result"] = "B"
df2.loc[2]
# Out:
# id                       3
# diagnosis_result         B
# radius                 NaN
# texture                 27
# perimeter              130
# area                  1203
# smoothness           0.125
# compactness           0.16
# symmetry             0.207
# fractal_dimension     0.06
# New_Column               2
# Name: 2, dtype: object

# %% [markdown]
# - >Setting values by position

# %%
df
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0     1                M    23.0       12        151   954       0.143
# 1     2                B     9.0       13        133  1326       0.143
# 2     3                M     NaN       27        130  1203       0.125
# 3     4                M    14.0       16         78   386       0.070
# 4     5                M     9.0       19        135  1297       0.141
# ..  ...              ...     ...      ...        ...   ...         ...
# 95   96                M    23.0       16        132  1264       0.091
# 96   97                B    22.0       14         78   451       0.105
# 97   98                B    19.0       27         62   295       0.102
# 98   99                B    21.0       24         74   413       0.090
# 99  100                M    16.0       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# ...

# %%
df.iat[0, 0] = 100
df
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   100                M    23.0       12        151   954       0.143
# 1     2                B     9.0       13        133  1326       0.143
# 2     3                M     NaN       27        130  1203       0.125
# 3     4                M    14.0       16         78   386       0.070
# 4     5                M     9.0       19        135  1297       0.141
# ..  ...              ...     ...      ...        ...   ...         ...
# 95   96                M    23.0       16        132  1264       0.091
# 96   97                B    22.0       14         78   451       0.105
# 97   98                B    19.0       27         62   295       0.102
# 98   99                B    21.0       24         74   413       0.090
# 99  100                M    16.0       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# ...

# %% [markdown]
# - >>Missing data

# %% [markdown]
# - >In order to check null values in Pandas DataFrame, we use isnull() function this function return dataframe of Boolean values which are True for NaN values

# %%
df1=df.copy()
df1.isnull()
# Out:
#        id  diagnosis_result  radius  texture  perimeter   area  smoothness  \
# 0   False             False   False    False      False  False       False
# 1   False             False   False    False      False  False       False
# 2   False             False    True    False      False  False       False
# 3   False             False   False    False      False  False       False
# 4   False             False   False    False      False  False       False
# ..    ...               ...     ...      ...        ...    ...         ...
# 95  False             False   False    False      False  False       False
# 96  False             False   False    False      False  False       False
# 97  False             False   False    False      False  False       False
# 98  False             False   False    False      False  False       False
# 99  False             False   False    False      False  False       False
#
#     compactness  symmetry  fractal_dimension
# ...

# %%
df1.notnull()
# Out:
#       id  diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   True              True    True     True       True  True        True
# 1   True              True    True     True       True  True        True
# 2   True              True   False     True       True  True        True
# 3   True              True    True     True       True  True        True
# 4   True              True    True     True       True  True        True
# ..   ...               ...     ...      ...        ...   ...         ...
# 95  True              True    True     True       True  True        True
# 96  True              True    True     True       True  True        True
# 97  True              True    True     True       True  True        True
# 98  True              True    True     True       True  True        True
# 99  True              True    True     True       True  True        True
#
#     compactness  symmetry  fractal_dimension
# 0          True      True               True
# ...

# %%
df
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   100                M    23.0       12        151   954       0.143
# 1     2                B     9.0       13        133  1326       0.143
# 2     3                M     NaN       27        130  1203       0.125
# 3     4                M    14.0       16         78   386       0.070
# 4     5                M     9.0       19        135  1297       0.141
# ..  ...              ...     ...      ...        ...   ...         ...
# 95   96                M    23.0       16        132  1264       0.091
# 96   97                B    22.0       14         78   451       0.105
# 97   98                B    19.0       27         62   295       0.102
# 98   99                B    21.0       24         74   413       0.090
# 99  100                M    16.0       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# ...

# %%
# sum of null value
df1.isnull().sum()
# Out:
# id                   0
# diagnosis_result     0
# radius               1
# texture              0
# perimeter            0
# area                 0
# smoothness           0
# compactness          3
# symmetry             0
# fractal_dimension    2
# dtype: int64

# %%
# filling the null values as o
df1.fillna(value= 0)
# Out:
#      id diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0   100                M    23.0       12        151   954       0.143
# 1     2                B     9.0       13        133  1326       0.143
# 2     3                M     0.0       27        130  1203       0.125
# 3     4                M    14.0       16         78   386       0.070
# 4     5                M     9.0       19        135  1297       0.141
# ..  ...              ...     ...      ...        ...   ...         ...
# 95   96                M    23.0       16        132  1264       0.091
# 96   97                B    22.0       14         78   451       0.105
# 97   98                B    19.0       27         62   295       0.102
# 98   99                B    21.0       24         74   413       0.090
# 99  100                M    16.0       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# ...
