# %%
import pandas as pd

# %%
df= pd.read_csv("drinks.csv")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %% [markdown]
# # Read Rows In csv

# %%
df= pd.read_csv("drinks.csv", nrows=5)
df
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# # Read Coulmns in CSV

# %%
df= pd.read_csv("drinks.csv", usecols=[0, 1, 2] )
df
# Out:
#          country  beer_servings  spirit_servings
# 0    Afghanistan              0                0
# 1        Albania             89              132
# 2        Algeria             25                0
# 3        Andorra            245              138
# 4         Angola            217               57
# ..           ...            ...              ...
# 188    Venezuela            333              100
# 189      Vietnam            111                2
# 190        Yemen              6                0
# 191       Zambia             32               19
# 192     Zimbabwe             64               18
#
# [193 rows x 3 columns]

# %% [markdown]
# # Read CSV Skiping Rows

# %%
df= pd.read_csv("drinks_1.csv")
df
# Out:
#                0              1                3              4  \
# 0        country  beer_servings  spirit_servings  wine_servings
# 1    Afghanistan              0                0              0
# 2        Albania             89              132             54
# 3        Algeria             25                0             14
# 4        Andorra            245              138            312
# ..           ...            ...              ...            ...
# 189    Venezuela            333              100              3
# 190      Vietnam            111                2              1
# 191        Yemen              6                0              0
# 192       Zambia             32               19              4
# 193     Zimbabwe             64               18              4
#
#                                 5              6
# 0    total_litres_of_pure_alcohol      continent
# 1                               0           Asia
# ...

# %%
df= pd.read_csv("drinks_1.csv", header=1)
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df= pd.read_csv("drinks_1.csv", skiprows=1)
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %% [markdown]
# # Skipping Spacific row

# %%
df= pd.read_csv("drinks.csv", skiprows=[1, 3])
df
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0              Albania             89              132             54
# 1              Andorra            245              138            312
# 2               Angola            217               57             45
# 3    Antigua & Barbuda            102              128             45
# 4            Argentina            193               25            221
# ..                 ...            ...              ...            ...
# 186          Venezuela            333              100              3
# 187            Vietnam            111                2              1
# 188              Yemen              6                0              0
# 189             Zambia             32               19              4
# 190           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             4.9         Europe
# ...

# %% [markdown]
# # Change Index With Particular Column

# %%
df= pd.read_csv("drinks.csv", index_col="country")
df
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# ...

# %%
df1= pd.read_csv("Fortune_10.csv")
df1
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %% [markdown]
# # Prefix coulmns

# %%
df= pd.read_csv("Fortune_10.csv", header=None, prefix="Col_umn_")
df
# Out:
#    Col_umn_0        Col_umn_1            Col_umn_2  Col_umn_3     Col_umn_4  \
# 0         ID             Name             Industry  Inception       Revenue
# 1          1          Lamtone          IT Services       2009  $11,757,018
# 2          2        Stripfind   Financial Services       2010  $12,329,371
# 3          3  Canecorporation               Health       2012  $10,597,009
# 4          4         Mattouch          IT Services       2013  $14,026,934
# 5          5        Techdrill               Health       2009  $10,573,990
# 6          6         Techline               Health       2006  $13,898,119
# 7          7          Cityace               Health       2010   $9,254,614
# 8          8   Kayelectronics               Health       2009   $9,451,943
# 9          9          Ganzlax          IT Services       2011  $14,001,180
# 10        10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Col_umn_5 Col_umn_6 Col_umn_7
# ...

# %% [markdown]
# # Rename Columns

# %%
df= pd.read_csv("Fortune_10.csv", names=[11,21,31,41,51,61,71])
df
# Out:
#                  11                   21         31            41  \
# ID             Name             Industry  Inception       Revenue
# 1           Lamtone          IT Services       2009  $11,757,018
# 2         Stripfind   Financial Services       2010  $12,329,371
# 3   Canecorporation               Health       2012  $10,597,009
# 4          Mattouch          IT Services       2013  $14,026,934
# 5         Techdrill               Health       2009  $10,573,990
# 6          Techline               Health       2006  $13,898,119
# 7           Cityace               Health       2010   $9,254,614
# 8    Kayelectronics               Health       2009   $9,451,943
# 9           Ganzlax          IT Services       2011  $14,001,180
# 10      Trantraxlax  Government Services       2011  $11,088,336
#
#                    51        61      71
# ID           Expenses    Profit  Growth
# 1   6,482,465 Dollars   5274553     30%
# 2     916,455 Dollars  11412916     20%
# ...

# %% [markdown]
# # Change Particular coumns Datatype

# %%
df= pd.read_csv("Fortune_10.csv", dtype={"ID": "float64"})
df
# Out:
#      ID             Name             Industry  Inception       Revenue  \
# 0   1.0          Lamtone          IT Services       2009  $11,757,018
# 1   2.0        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  Canecorporation               Health       2012  $10,597,009
# 3   4.0         Mattouch          IT Services       2013  $14,026,934
# 4   5.0        Techdrill               Health       2009  $10,573,990
# 5   6.0         Techline               Health       2006  $13,898,119
# 6   7.0          Cityace               Health       2010   $9,254,614
# 7   8.0   Kayelectronics               Health       2009   $9,451,943
# 8   9.0          Ganzlax          IT Services       2011  $14,001,180
# 9  10.0      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...
