# %%
import pandas as pd

# %%
d=pd.read_csv("drinks.csv")
df=d.copy()
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.pivot_table(index="continent")
# Out:
#                beer_servings  spirit_servings  total_litres_of_pure_alcohol  \
# continent
# Africa             61.471698        16.339623                      3.007547
# Asia               37.906977        62.255814                      2.220930
# Europe            193.777778       132.555556                      8.617778
# North America     145.434783       165.739130                      5.995652
# Oceania            89.687500        58.437500                      3.381250
# South America     175.083333       114.750000                      6.308333
#
#                wine_servings
# continent
# Africa             16.264151
# Asia                9.279070
# Europe            142.222222
# North America      24.521739
# Oceania            35.625000
# South America      62.416667

# %%
df.pivot_table(index="continent", columns="country")
# Out:
#               beer_servings                                           \
# country             Albania Algeria Andorra Angola Antigua & Barbuda
# continent
# Africa                  NaN    25.0     NaN  217.0               NaN
# Asia                    NaN     NaN     NaN    NaN               NaN
# Europe                 89.0     NaN   245.0    NaN               NaN
# North America           NaN     NaN     NaN    NaN             102.0
# Oceania                 NaN     NaN     NaN    NaN               NaN
# South America           NaN     NaN     NaN    NaN               NaN
#
#                                                               ...  \
# country       Argentina Armenia Australia Austria Azerbaijan  ...
# continent                                                     ...
# Africa              NaN     NaN       NaN     NaN        NaN  ...
# Asia                NaN     NaN       NaN     NaN        NaN  ...
# Europe              NaN    21.0       NaN   279.0       21.0  ...
# ...

# %%
df.pivot_table(index="continent", aggfunc=["sum"])
# Out:
#                         sum                                               \
#               beer_servings spirit_servings total_litres_of_pure_alcohol
# continent
# Africa                 3258             866                        159.4
# Asia                   1630            2677                         95.5
# Europe                 8720            5965                        387.8
# North America          3345            3812                        137.9
# Oceania                1435             935                         54.1
# South America          2101            1377                         75.7
#
#
#               wine_servings
# continent
# Africa                  862
# Asia                    399
# Europe                 6400
# North America           564
# Oceania                 570
# South America           749

# %%
df.pivot_table(index="continent")
# Out:
#                beer_servings  spirit_servings  total_litres_of_pure_alcohol  \
# continent
# Africa             61.471698        16.339623                      3.007547
# Asia               37.906977        62.255814                      2.220930
# Europe            193.777778       132.555556                      8.617778
# North America     145.434783       165.739130                      5.995652
# Oceania            89.687500        58.437500                      3.381250
# South America     175.083333       114.750000                      6.308333
#
#                wine_servings
# continent
# Africa             16.264151
# Asia                9.279070
# Europe            142.222222
# North America      24.521739
# Oceania            35.625000
# South America      62.416667

# %%
df.pivot_table(index="continent", aggfunc="sum", margins=True)
# Out:
#                beer_servings  spirit_servings  total_litres_of_pure_alcohol  \
# continent
# Africa                  3258              866                         159.4
# Asia                    1630             2677                          95.5
# Europe                  8720             5965                         387.8
# North America           3345             3812                         137.9
# Oceania                 1435              935                          54.1
# South America           2101             1377                          75.7
# All                    20489            15632                         910.4
#
#                wine_servings
# continent
# Africa                   862
# Asia                     399
# Europe                  6400
# North America            564
# Oceania                  570
# South America            749
# All                     9544
