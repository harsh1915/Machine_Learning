# %%
import pandas as pd

# %%
df1=pd.DataFrame({
    "A":[1, 2, 3],
    "B":[10, 20, 30]
})

df2=pd.DataFrame({
    "C":[4, 5, 6],
    "D":[40, 50, 60]
})
display(df1,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    C   D
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1.join(df2)
# Out:
#    A   B  C   D
# 0  1  10  4  40
# 1  2  20  5  50
# 2  3  30  6  60

# %%
df1=pd.DataFrame({
    "A":[1, 2, 3],
    "B":[10, 20, 30]
})

df2=pd.DataFrame({
    "C":[4, 5],
    "D":[40, 50]
})
display(df1,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    C   D
# 0  4  40
# 1  5  50

# %%
df1.join(df2)
# Out:
#    A   B    C     D
# 0  1  10  4.0  40.0
# 1  2  20  5.0  50.0
# 2  3  30  NaN   NaN

# %%
df1=pd.DataFrame({
    "A":[1, 2, 3],
    "B":[10, 20, 30]
})

df2=pd.DataFrame({
    "A":[4, 5, 6],
    "D":[40, 50, 60]
})
display(df1,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    A   D
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1.join(df2, lsuffix="_1")
# Out:
#    A_1   B  A   D
# 0    1  10  4  40
# 1    2  20  5  50
# 2    3  30  6  60

# %%
df1.join(df2, rsuffix="_1")
# Out:
#    A   B  A_1   D
# 0  1  10    4  40
# 1  2  20    5  50
# 2  3  30    6  60
