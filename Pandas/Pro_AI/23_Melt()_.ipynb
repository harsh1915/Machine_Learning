# %%
import pandas as pd
d=pd.read_csv("drinks.csv",nrows=9)
df=d.copy()
df
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# ...

# %%
df.melt()
# Out:
#                         variable              value
# 0                        country        Afghanistan
# 1                        country            Albania
# 2                        country            Algeria
# 3                        country            Andorra
# 4                        country             Angola
# 5                        country  Antigua & Barbuda
# 6                        country          Argentina
# 7                        country            Armenia
# 8                        country          Australia
# 9                  beer_servings                  0
# 10                 beer_servings                 89
# 11                 beer_servings                 25
# 12                 beer_servings                245
# 13                 beer_servings                217
# 14                 beer_servings                102
# 15                 beer_servings                193
# 16                 beer_servings                 21
# ...

# %%
df.melt(id_vars=["country"])
# Out:
#               country                      variable          value
# 0         Afghanistan                 beer_servings              0
# 1             Albania                 beer_servings             89
# 2             Algeria                 beer_servings             25
# 3             Andorra                 beer_servings            245
# 4              Angola                 beer_servings            217
# 5   Antigua & Barbuda                 beer_servings            102
# 6           Argentina                 beer_servings            193
# 7             Armenia                 beer_servings             21
# 8           Australia                 beer_servings            261
# 9         Afghanistan               spirit_servings              0
# 10            Albania               spirit_servings            132
# 11            Algeria               spirit_servings              0
# 12            Andorra               spirit_servings            138
# ...

# %%
df.melt(id_vars=["country", "continent"])
# Out:
#               country      continent                      variable  value
# 0         Afghanistan           Asia                 beer_servings    0.0
# 1             Albania         Europe                 beer_servings   89.0
# 2             Algeria         Africa                 beer_servings   25.0
# 3             Andorra         Europe                 beer_servings  245.0
# 4              Angola         Africa                 beer_servings  217.0
# 5   Antigua & Barbuda  North America                 beer_servings  102.0
# 6           Argentina  South America                 beer_servings  193.0
# 7             Armenia         Europe                 beer_servings   21.0
# 8           Australia        Oceania                 beer_servings  261.0
# 9         Afghanistan           Asia               spirit_servings    0.0
# 10            Albania         Europe               spirit_servings  132.0
# 11            Algeria         Africa               spirit_servings    0.0
# ...

# %%
df.melt(id_vars=["country"], value_vars="continent", var_name="Category", value_name="contint")
# Out:
#              country   Category        contint
# 0        Afghanistan  continent           Asia
# 1            Albania  continent         Europe
# 2            Algeria  continent         Africa
# 3            Andorra  continent         Europe
# 4             Angola  continent         Africa
# 5  Antigua & Barbuda  continent  North America
# 6          Argentina  continent  South America
# 7            Armenia  continent         Europe
# 8          Australia  continent        Oceania
