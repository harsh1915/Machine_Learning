# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1=df.copy()
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1.shape
# Out:
# (768, 9)

# %%
df1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df1.size
# Out:
# 6912

# %%
# exc:
# list of column
# numeric column
# cetagorical column
# total null
# %of null
# desplay column name ,total null ,%null in df
# how many zeros in column
# glucos,bp,skinthikness,insulin,bmi find out zeros replace zeros with mean

# %%
# list of column
list(df1.columns)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# numeric column
df1.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# cetagorical column
df1[["Age", "Pregnancies"]]
# Out:
#      Age  Pregnancies
# 0     50            6
# 1     31            1
# 2     32            8
# 3     21            1
# 4     33            0
# ..   ...          ...
# 763   63           10
# 764   27            2
# 765   30            5
# 766   47            1
# 767   23            1
#
# [768 rows x 2 columns]

# %%
# glucos,bp,skinthikness,insulin,bmi find out zeros replace zeros with mean
ls=["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]
for i in ls:
    df1=df1.replace({i: 0}, np.nan)

# %%
# total null
df1.isnull().sum().sum()
# Out:
# 652

# %%
# %of null
(df1.isnull().sum().sum()/df1.size)*100
# Out:
# 9.43287037037037

# %%
c_null=[]
for i in list(df1.columns):
    c_null.append(df1[i].isnull().sum().sum())

# %%
c_null_percentage=[]
for i in c_null:
    c_null_percentage.append(i/len(df1.index)*100)

# %%
# desplay column name ,total null ,%null in df
df2= pd.DataFrame({
    "Column Name":list(df1.columns),
    "Total Null":c_null,
    "Null percentage":c_null_percentage
})
df2
# Out:
#                 Column Name  Total Null  Null percentage
# 0               Pregnancies           0         0.000000
# 1                   Glucose           5         0.651042
# 2             BloodPressure          35         4.557292
# 3             SkinThickness         227        29.557292
# 4                   Insulin         374        48.697917
# 5                       BMI          11         1.432292
# 6  DiabetesPedigreeFunction           0         0.000000
# 7                       Age           0         0.000000
# 8                   Outcome           0         0.000000

# %%
list_zeros= []
for i in list(df1.columns):
    list_zeros.append(sum(df1[i]==0))

# %%
df2= pd.DataFrame({
    "Column Name":list(df1.columns),
    "Total Zeros":list_zeros
})
df2
# Out:
#                 Column Name  Total Zeros
# 0               Pregnancies          111
# 1                   Glucose            0
# 2             BloodPressure            0
# 3             SkinThickness            0
# 4                   Insulin            0
# 5                       BMI            0
# 6  DiabetesPedigreeFunction            0
# 7                       Age            0
# 8                   Outcome          500

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
list_zeros= []
for i in list(df1.columns):
    list_zeros.append(sum(df1[i]==0))
    
df2= pd.DataFrame({
    "Column Name":list(df1.columns),
    "Total Zeros":list_zeros
})
df2
# Out:
#                 Column Name  Total Zeros
# 0               Pregnancies          111
# 1                   Glucose            0
# 2             BloodPressure            0
# 3             SkinThickness            0
# 4                   Insulin            0
# 5                       BMI            0
# 6  DiabetesPedigreeFunction            0
# 7                       Age            0
# 8                   Outcome          500

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ls=["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]
for i in ls:
    df1=df1.replace({i: np.nan}, df1[i].mean())

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
na=df.isnull().sum()
na
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
total=df.isnull().count()

# %%
ndf=pd.concat((total,na), keys=["total_na","na"], axis=1)
ndf
# Out:
#                           total_na  na
# Pregnancies                    768   0
# Glucose                        768   0
# BloodPressure                  768   0
# SkinThickness                  768   0
# Insulin                        768   0
# BMI                            768   0
# DiabetesPedigreeFunction       768   0
# Age                            768   0
# Outcome                        768   0

# %%
ls=["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# %%
for i in ls:
    num=df[df[i]==0].count()
    print(1,num)
# Out:
# 1 Pregnancies                 5
# Glucose                     5
# BloodPressure               5
# SkinThickness               5
# Insulin                     5
# BMI                         5
# DiabetesPedigreeFunction    5
# Age                         5
# Outcome                     5
# dtype: int64
# 1 Pregnancies                 35
# Glucose                     35
# BloodPressure               35
# SkinThickness               35
# Insulin                     35
# BMI                         35
# DiabetesPedigreeFunction    35
# Age                         35
# Outcome                     35
# dtype: int64
# 1 Pregnancies                 227
# Glucose                     227
# BloodPressure               227
# SkinThickness               227
# Insulin                     227
# BMI                         227
# DiabetesPedigreeFunction    227
# Age                         227
# Outcome                     227
# dtype: int64
# 1 Pregnancies                 374
# ...

# %%
for col in ls:
    total_na=df1.isna().sum().sort_values(ascending=False)
total_na
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ls
# Out:
# ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# %%
for col in ls:
    df[col]=df[col].replace(0,np.nan)

# %%
for col in ls:
    total_na=df.isna().sum().sort_values(ascending=False)
total_na
# Out:
# Insulin                     374
# SkinThickness               227
# BloodPressure                35
# BMI                          11
# Glucose                       5
# Pregnancies                   0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
per=total_na/total
per
# Out:
# Age                         0.000000
# BMI                         0.014323
# BloodPressure               0.045573
# DiabetesPedigreeFunction    0.000000
# Glucose                     0.006510
# Insulin                     0.486979
# Outcome                     0.000000
# Pregnancies                 0.000000
# SkinThickness               0.295573
# dtype: float64

# %%
for col in ls:
    df=df.replace({col: np.nan}, df[col].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
for col in ls:
    df[col]=df[col].replace(0,np.nan)

# %%
null=pd.DataFrame(df.isna().sum().sort_values(ascending=False))
null
# Out:
#                           0
# Pregnancies               0
# Glucose                   0
# BloodPressure             0
# SkinThickness             0
# Insulin                   0
# BMI                       0
# DiabetesPedigreeFunction  0
# Age                       0
# Outcome                   0

# %%
# nulls=null(null>0)

# %%
null.columns=["null_Count"]

# %%
fea=null.index
fea
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
null.index.name="features"

# %%
null
# Out:
#                           0
# Pregnancies               0
# Glucose                   0
# BloodPressure             0
# SkinThickness             0
# Insulin                   0
# BMI                       0
# DiabetesPedigreeFunction  0
# Age                       0
# Outcome                   0

# %%
for col in null["null"]

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
for col in null["null_count"]:
    print(col)

# %%
import matplotlib.pyplot as plt
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
plt.boxplot(df["Insulin"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22bb31c7af0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22bb31dc190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22bb31b9580>],
#  'medians': [<matplotlib.lines.Line2D at 0x22bb31dc8b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22bb31dcc40>],
#  'means': []}

# %%
plt.boxplot(df["BMI"])
plt.boxplot(df["Glucose"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22bb5347760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22bb5347e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22bb53473d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22bb53505e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22bb5350970>],
#  'means': []}

# %%
plt.subplot(1,2,1)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.boxplot(df["BMI"])
sns.boxplot(df["Glucose"])
# Out:
# C:\Users\PRIYANSHI\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\PRIYANSHI\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Glucose'>

# %%
plt.subplot(121)
sns.boxplot(df["BMI"])

plt.subplot(122)
sns.boxplot(df["Glucose"])
# Out:
# C:\Users\PRIYANSHI\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\PRIYANSHI\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Glucose'>
