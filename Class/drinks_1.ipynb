# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv("drinks.csv")
df=d.copy()
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1= pd.read_csv("drinks.csv", nrows=5)
df1
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df1= pd.read_csv("drinks.csv", usecols=[0, 1, 2] )
df1
# Out:
#          country  beer_servings  spirit_servings
# 0    Afghanistan              0                0
# 1        Albania             89              132
# 2        Algeria             25                0
# 3        Andorra            245              138
# 4         Angola            217               57
# ..           ...            ...              ...
# 188    Venezuela            333              100
# 189      Vietnam            111                2
# 190        Yemen              6                0
# 191       Zambia             32               19
# 192     Zimbabwe             64               18
#
# [193 rows x 3 columns]

# %%
df1= pd.read_csv("drinks.csv", skiprows=1)
df1
# Out:
#            Afghanistan    0  0.1  0.2   0.0           Asia
# 0              Albania   89  132   54   4.9         Europe
# 1              Algeria   25    0   14   0.7         Africa
# 2              Andorra  245  138  312  12.4         Europe
# 3               Angola  217   57   45   5.9         Africa
# 4    Antigua & Barbuda  102  128   45   4.9  North America
# ..                 ...  ...  ...  ...   ...            ...
# 187          Venezuela  333  100    3   7.7  South America
# 188            Vietnam  111    2    1   2.0           Asia
# 189              Yemen    6    0    0   0.1           Asia
# 190             Zambia   32   19    4   2.5         Africa
# 191           Zimbabwe   64   18    4   4.7         Africa
#
# [192 rows x 6 columns]

# %%
df.isna()
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 0      False          False            False          False
# 1      False          False            False          False
# 2      False          False            False          False
# 3      False          False            False          False
# 4      False          False            False          False
# ..       ...            ...              ...            ...
# 188    False          False            False          False
# 189    False          False            False          False
# 190    False          False            False          False
# 191    False          False            False          False
# 192    False          False            False          False
#
#      total_litres_of_pure_alcohol  continent
# 0                           False      False
# 1                           False      False
# 2                           False      False
# 3                           False      False
# ...

# %%
df.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df1=df.copy()
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df1.replace("Europe", "Euro")
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9           Euro
# ...

# %%
df1.replace("Europe", np.nan)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9            NaN
# ...

# %%
df.loc[0]
# Out:
# country                         Afghanistan
# beer_servings                             0
# spirit_servings                           0
# wine_servings                             0
# total_litres_of_pure_alcohol            0.0
# continent                              Asia
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.loc[df["beer_servings"]> 100]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# 6            Argentina            193               25            221
# 8            Australia            261               72            212
# ..                 ...            ...              ...            ...
# 182     United Kingdom            219              126            195
# 184                USA            249              158             84
# 185            Uruguay            115               35            220
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
#
#      total_litres_of_pure_alcohol      continent
# 3                            12.4         Europe
# ...

# %%
df.loc[df["beer_servings"]> 100, ["country"]]
# Out:
#                country
# 3              Andorra
# 4               Angola
# 5    Antigua & Barbuda
# 6            Argentina
# 8            Australia
# ..                 ...
# 182     United Kingdom
# 184                USA
# 185            Uruguay
# 188          Venezuela
# 189            Vietnam
#
# [79 rows x 1 columns]

# %%
df.iloc[0]
# Out:
# country                         Afghanistan
# beer_servings                             0
# spirit_servings                           0
# wine_servings                             0
# total_litres_of_pure_alcohol            0.0
# continent                              Asia
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia

# %%
df.iloc[:]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.iloc[: , [0]]
# Out:
#          country
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3        Andorra
# 4         Angola
# ..           ...
# 188    Venezuela
# 189      Vietnam
# 190        Yemen
# 191       Zambia
# 192     Zimbabwe
#
# [193 rows x 1 columns]

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
grp=df.groupby(by=["continent"])
grp.groups
# Out:
# {'Africa': [2, 4, 18, 22, 26, 27, 28, 29, 31, 33, 34, 38, 39, 47, 49, 53, 55, 56, 58, 62, 63, 66, 70, 71, 88, 95, 96, 97, 100, 101, 104, 107, 108, 114, 115, 117, 123, 124, 142, 148, 150, 152, 153, 158, 159, 162, 164, 172, 175, 179, 183, 191, 192], 'Asia': [0, 12, 13, 19, 24, 30, 36, 46, 77, 78, 79, 80, 82, 85, 86, 87, 90, 91, 92, 94, 102, 103, 112, 116, 119, 127, 128, 134, 137, 138, 141, 149, 154, 161, 167, 168, 169, 171, 176, 177, 181, 186, 189, 190], 'Europe': [1, 3, 7, 9, 10, 15, 16, 21, 25, 42, 44, 45, 48, 57, 60, 61, 64, 65, 67, 75, 76, 81, 83, 93, 98, 99, 105, 111, 113, 120, 126, 135, 136, 139, 140, 147, 151, 155, 156, 160, 165, 166, 170, 180, 182], 'North America': [5, 11, 14, 17, 32, 41, 43, 50, 51, 54, 68, 69, 73, 74, 84, 109, 122, 130, 143, 144, 145, 174, 184], 'Oceania': [8, 40, 59, 89, 106, 110, 118, 121, 125, 129, 131, 146, 157, 173, 178, 187], 'South America': [6, 20, 23, 35, 37, 52, 72, 132, 133, 163, 185, 188]}

# %%
grp.get_group("Africa")
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
grp.get_group("Asia")
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
grp.sum()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa                  3258              866            862
# Asia                    1630             2677            399
# Europe                  8720             5965           6400
# North America           3345             3812            564
# Oceania                 1435              935            570
# South America           2101             1377            749
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                159.4
# Asia                                   95.5
# Europe                                387.8
# North America                         137.9
# Oceania                                54.1
# South America                          75.7

# %%
grp.mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
grp.describe().T
# Out:
# continent                               Africa        Asia      Europe  \
# beer_servings                count   53.000000   44.000000   45.000000
#                              mean    61.471698   37.045455  193.777778
#                              std     80.557816   49.469725   99.631569
#                              min      0.000000    0.000000    0.000000
#                              25%     15.000000    4.250000  127.000000
#                              50%     32.000000   17.500000  219.000000
#                              75%     76.000000   60.500000  270.000000
#                              max    376.000000  247.000000  361.000000
# spirit_servings              count   53.000000   44.000000   45.000000
#                              mean    16.339623   60.840909  132.555556
#                              std     28.102794   84.362160   77.589115
#                              min      0.000000    0.000000    0.000000
# ...

# %%
grp.agg(["max", "min"])
# Out:
#                       country                    beer_servings      \
#                           max                min           max min
# continent
# Africa               Zimbabwe            Algeria           376   0
# Asia                    Yemen        Afghanistan           247   0
# Europe         United Kingdom            Albania           361   0
# North America             USA  Antigua & Barbuda           285   1
# Oceania               Vanuatu          Australia           306   0
# South America       Venezuela          Argentina           333  93
#
#               spirit_servings     wine_servings      \
#                           max min           max min
# continent
# Africa                    152   0           233   0
# Asia                      326   0           123   0
# Europe                    373   0           370   0
# North America             438  68           100   1
# Oceania                   254   0           212   0
# ...

# %%
df1=df1.replace(0, np.nan)
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             NaN           Asia
# 1                             4.9         Europe
# ...

# %%
df1.dropna(thresh=3)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania           89.0            132.0           54.0
# 2              Algeria           25.0              NaN           14.0
# 3              Andorra          245.0            138.0          312.0
# 4               Angola          217.0             57.0           45.0
# 5    Antigua & Barbuda          102.0            128.0           45.0
# ..                 ...            ...              ...            ...
# 188          Venezuela          333.0            100.0            3.0
# 189            Vietnam          111.0              2.0            1.0
# 190              Yemen            6.0              NaN            NaN
# 191             Zambia           32.0             19.0            4.0
# 192           Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 1                             4.9         Europe
# ...
