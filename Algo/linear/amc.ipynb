# %%
import seaborn as se
import pandas as pd

# %%
df = pd.read_csv("AMC.csv")
df1= df.round(2)
df1
# Out:
#             Date   Open   High    Low  Close  Adj Close     Volume
# 0     2013-12-18  19.18  19.79  18.90  18.90      13.59    5457200
# 1     2013-12-19  18.90  19.49  18.81  19.49      14.02    1605400
# 2     2013-12-20  19.65  19.77  19.40  19.68      14.15     737100
# 3     2013-12-23  19.79  19.99  19.50  19.74      14.20     698100
# 4     2013-12-24  19.74  19.82  19.50  19.53      14.05     213700
# ...          ...    ...    ...    ...    ...        ...        ...
# 1957  2021-09-28  38.90  39.13  36.88  36.99      36.99   39523300
# 1958  2021-09-29  37.25  38.26  35.37  35.54      35.54   43007800
# 1959  2021-09-30  35.19  41.78  33.74  38.06      38.06  102819800
# 1960  2021-10-01  39.41  40.13  37.75  38.46      38.46   65919000
# 1961  2021-10-04  38.90  39.03  36.33  36.77      36.77   39836400
#
# [1962 rows x 7 columns]

# %%
df1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1962.000000  1962.000000  1962.000000  1962.000000  1962.000000
# mean     20.034210    20.484276    19.563445    20.014918    16.374032
# std      10.561166    10.925572    10.307299    10.594228     8.881067
# min       1.990000     2.030000     1.910000     1.980000     1.980000
# 25%      12.075000    12.525000    11.760000    12.185000    10.855000
# 50%      20.190000    20.665000    19.895000    20.220000    15.920000
# 75%      28.070000    28.550000    27.585000    28.052500    21.267500
# max      61.340000    72.620000    56.850000    62.550000    62.550000
#
#              Volume
# count  1.962000e+03
# mean   1.569135e+07
# std    6.343020e+07
# min    3.430000e+04
# 25%    2.625250e+05
# 50%    1.392200e+06
# 75%    3.368575e+06
# max    1.222342e+09

# %%
se.pairplot(df1)

# %%
df1.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
x = df1.iloc[:,1]
x
# Out:
# 0       19.18
# 1       18.90
# 2       19.65
# 3       19.79
# 4       19.74
#         ...
# 1957    38.90
# 1958    37.25
# 1959    35.19
# 1960    39.41
# 1961    38.90
# Name: Open, Length: 1962, dtype: float64

# %%
y = df1.iloc[:,4]
y
# Out:
# 0       18.90
# 1       19.49
# 2       19.68
# 3       19.74
# 4       19.53
#         ...
# 1957    36.99
# 1958    35.54
# 1959    38.06
# 1960    38.46
# 1961    36.77
# Name: Close, Length: 1962, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)

# %%
w=0.50
b=0.75
lr=0.0000001
for i in range(30):
    yh=b+w*x
    dea=-2*((y-yh)*x).sum()
    deb=-2*(y-yh).sum() 
    w=w-lr*dea
    b=b-lr * deb
    error=((y-yh)**2).mean()
    print(error)

# print(w,b)
# Out:
# 114.2128758409788
# 73.2008247369978
# 47.05471193515427
# 30.385969135392035
# 19.75926285818542
# 12.984490750107845
# 8.665413305716385
# 5.911896439035591
# 4.156459651249629
# 3.037321361796264
# 2.3238376766435285
# 1.8689679261928906
# 1.578970376648449
# 1.3940825644749955
# 1.2762045751181255
# 1.2010468561867775
# 1.1531242717623698
# 1.1225646994377694
# 1.1030744391553744
# 1.090641115583701
# 1.0827067492108682
# 1.07764057056918
# 1.0744029274469442
# 1.072331018177335
# 1.0710022917911863
# 1.070147362542317
# 1.0695944909588508
# 1.0692341892648431
# 1.068996656540532
# 1.0688373931295305

# %%
yh
# Out:
# 0       19.339759
# 1       19.068615
# 2       19.794893
# 3       19.930465
# 4       19.882047
#           ...
# 1957    38.436026
# 1958    36.838215
# 1959    34.843371
# 1960    38.929895
# 1961    38.436026
# Name: Open, Length: 1962, dtype: float64

# %%
plt.scatter(x, y)
# plt.plot(x, yh)
plt.plot(x, yh,'r')

# %%
yp=b+w*20
yp
# Out:
# 20.13657959949047
